# %% [markdown]
# <a href="https://colab.research.google.com/github/FidanKerimova56/teamWork/blob/Said/miscellaneous.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
years_experience = {
    'Said': 3,
    'Luke': 3,
    'Kelly': 6,
    'Nargiz': 4


}

# %%
for value in years_experience.values():
    print(value)
# Out:
# 3
# 3
# 6
# 4

# %%
import my_modul
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-667ed5cacdfd> in <cell line: 0>()
# ----> 1 import my_modul
#
# ModuleNotFoundError: No module named 'my_modul'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import job_analyzer

job_analyzer.calculate_salary(100000)

# %%
from job_analyzer import calculate_salary

calculate_salary(100000)

# %%
help(calculate_salary)

# %%
salary_list = [98000,101000,102000,99000,97000]

# %%
from statistics import mean, median, mode

mean(salary_list)

# %%
median(salary_list)

# %%
mode(salary_list)

# %%
from datetime import datetime

# %%
datetime.now()
print(datetime.now())

# %%
from my_module import skill_set

# %%
skill_set
# Out:
# ['Python', 'SQL', 'Excel']

# %%
data_science_jobs = [
    "Data Scientist", "Machine Learning Engineer", "Data Analyst", "AI Researcher",
    "Deep Learning Engineer", "Big Data Engineer", "Data Engineer", "Business Intelligence Analyst",
    "Statistician", "Predictive Modeler", "Computer Vision Engineer", "NLP Engineer",
    "Data Architect", "AI Product Manager", "Cloud Data Engineer", "Research Scientist",
    "Quantitative Analyst", "Bioinformatics Scientist", "Geospatial Data Scientist",
    "Data Mining Specialist", "Marketing Data Analyst", "Customer Insights Analyst",
    "Operations Research Analyst", "Data Visualization Specialist", "Decision Scientist",
    "Data Science Consultant", "Retail Data Analyst", "Financial Data Scientist",
    "Fraud Detection Analyst", "Cybersecurity Data Scientist", "Risk Analyst",
    "Econometrician", "ETL Developer", "Supply Chain Data Analyst", "Sports Data Scientist",
    "Healthcare Data Scientist", "Pharmaceutical Data Analyst", "Agricultural Data Scientist",
    "Human Resources Data Analyst", "Climate Data Scientist", "Manufacturing Data Analyst",
    "IoT Data Scientist", "AI Ethics Researcher", "Epidemiology Data Analyst",
    "Speech Recognition Engineer", "Robotics Data Scientist", "Self-Driving Car Engineer",
    "Sentiment Analysis Specialist", "Knowledge Graph Engineer", "AI Software Engineer",
    "AI Solutions Architect", "Data Governance Specialist", "Experimentation Scientist",
    "Data Strategy Consultant", "Graph Data Scientist", "Energy Data Scientist",
    "Data Quality Analyst", "Customer Data Scientist", "Logistics Data Scientist",
    "E-commerce Data Analyst", "Education Data Analyst", "HR Analytics Consultant",
    "Public Policy Data Analyst", "Biomedical Data Scientist", "Clinical Data Scientist",
    "AI Developer", "Data Journalism Specialist", "Personalization Data Scientist",
    "Digital Marketing Data Scientist", "Insurance Data Scientist", "Telecom Data Scientist",
    "Gaming Data Analyst", "Music Data Analyst", "Text Mining Specialist",
    "Real Estate Data Analyst", "Causal Inference Scientist", "Advertising Data Analyst",
    "Pricing Analyst", "Speech AI Engineer", "Anomaly Detection Specialist",
    "MLOps Engineer", "Cloud AI Engineer", "Synthetic Data Engineer",
    "Personal Finance Data Scientist", "AI Fairness Researcher", "Supply Chain Optimization Scientist",
    "Crowdsourcing Data Scientist", "Data Engineer (Streaming Data)", "Healthcare AI Specialist",
    "Blockchain Data Scientist", "Time Series Analyst", "Bayesian Statistician",
    "Insurance Risk Modeler", "AI Chatbot Developer", "Recommendation Systems Engineer",
    "AI Personalization Engineer", "Healthcare Predictive Analytics Specialist",
    "Financial Markets Data Scientist", "Operations Data Scientist", "AI Hardware Engineer",
    "Cyber Threat Intelligence Analyst", "Autonomous Systems Engineer", "Industrial AI Specialist"
]

# %%
test_date = data_science_jobs[0]['job_date']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-af5333214ab5> in <cell line: 0>()
# ----> 1 test_date = data_science_jobs[0]['job_date']
#
# TypeError: string indices must be integers, not 'str'

# %%
data_science_jobs = list(data_science_jobs)

# %%
test_date = [data_science_jobs[0]
# Out:
#   File "<ipython-input-30-e573b929457b>", line 1
#     test_date = [data_science_jobs[0]
#                                      ^
# SyntaxError: incomplete input

# %%
file = open('sample_data/california_housing_test.csv')

content = file.read()

file.close()

# %%
import pandas as pd

contents = pd.read_csv('sample_data/california_housing_test.csv')

contents['total_bedrooms'].sum()
# Out:
# np.float64(1589852.0)

# %%
import pandas as pd

contents = pd.read_csv('sample_data/california_housing_test.csv')

contents['total_rooms'].sum()
# Out:
# np.float64(7798736.0)

# %%
# !pip install pyjokes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import pyjokes

# %%
help(pyjokes)
# Out:
# Help on package pyjokes:
#
# NAME
#     pyjokes
#
# PACKAGE CONTENTS
#     cli (package)
#     exc
#     jokes_cs
#     jokes_de
#     jokes_en
#     jokes_es
#     jokes_eu
#     jokes_fr
#     jokes_gl
#     jokes_hu
#     jokes_it
#     jokes_lt
#     jokes_pl
#     jokes_ru
#     jokes_sv
#     pyjokes
#
# DATA
#     CATEGORY_VALUES = {'all', 'chuck', 'neutral'}
#     LANGUAGE_VALUES = {'cs', 'de', 'en', 'es', 'eu', 'fr', ...}
#
# FILE
#     /usr/local/lib/python3.11/dist-packages/pyjokes/__init__.py

# %%
pyjokes.get_joke()
# Out:
# "An SQL query goes into a bar, walks up to two tables and asks, 'Can I join you?'"

# %%
my_list = SaidsList()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3fb87a5241c7> in <cell line: 0>()
# ----> 1 my_list = SaidsList()
#
# NameError: name 'SaidsList' is not defined

# %%
data_salary = BaseSalary(100000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6f0eaa7f3eea> in <cell line: 0>()
# ----> 1 data_salary = BaseSalary(100000)
#
# NameError: name 'BaseSalary' is not defined

# %%
# assigning list to 'SaidsList'
SaidsList = [1,2,5,8]

# trying to call 'SaidsList' as a function

my_list = SaidsList()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-d1dce3675a90> in <cell line: 0>()
#       4 # trying to call 'SaidsList' as a function
#       5
# ----> 6 my_list = SaidsList()
#
# TypeError: 'list' object is not callable

# %%
import random

salary = [random.randint(50000,100000) for _ in range(100_000_000)]

# %%
salary_list = [90000,120000,100000,98000,150000]

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 9.32 µs ± 2.07 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 10 µs ± 2.67 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
